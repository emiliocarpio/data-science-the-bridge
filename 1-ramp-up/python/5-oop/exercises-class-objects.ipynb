# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas ultimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# * Método que calcula la media de ventas de los ultimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:
    tipo = "Electrodomésticos"
    abierta = True

    def __init__(self, nombre, direccion, empleados, ventas_3_meses):
        self.nombre = nombre
        self.direccion = direccion
        self.empleados = empleados
        self.ventas_3_meses = list(ventas_3_meses)
    
    def ventas_mes(self):
        self.ventas_3_meses
        suma_ventas = sum(self.ventas_3_meses)
        return "Las ventas de los últimos meses han sido: " + str(suma_ventas)

    def media_ventas(self):
        self.ventas_3_meses
        self.empleados

        suma_ventas = sum(self.ventas_3_meses)
        media_ventas = suma_ventas / self.empleados
        return "La media de ventas por empleado es " + str(media_ventas) 

    def dire_name(self):
        return self.nombre + ". " + self.direccion 

    def last_month(self):
        return "Las ventas del último mes son: " + str(self.ventas_3_meses[2])

    def sales_forecast(self):
        budget = int(input("Introduce el budget de Marketing"))
        self.ventas_3_meses

        if budget < 1000:
            self.ventas_3_meses = sum(self.ventas_3_meses)*1.2
        elif budget >= 1000:
            self.ventas_3_meses = sum(self.ventas_3_meses)*1.5
        return "Las ventas de los últimos meses son: " + str(self.ventas_3_meses)

tienda1 = Tienda("ElectroDepot", "Av.Madrid, 12", 56, [144, 134, 4532])
tienda2 = Tienda("BricoDepot", "Calle Juliano, 12", 6, [142, 134, 4432])
tienda3 = Tienda("MediaMarkt", "Av. Prim y Mas, 12", 51, [324, 137, 4032])

print(tienda1.last_month())
print(tienda1.dire_name())
print(tienda1.ventas_mes())
print(tienda1.media_ventas())
print(tienda1.sales_forecast())

print(tienda2.last_month())
print(tienda2.dire_name())
print(tienda2.ventas_mes())
print(tienda2.media_ventas())
print(tienda2.sales_forecast())

print(tienda3.last_month())
print(tienda3.dire_name())
print(tienda3.ventas_mes())
print(tienda3.media_ventas())
print(tienda3.sales_forecast())
# Out:
# Las ventas del último mes son: 4532
# ElectroDepot. Av.Madrid, 12
# Las ventas de los últimos meses han sido: 7000
# La media de ventas por empleado es 125.0
# Las ventas de los últimos meses son: 8400.0
# Las ventas del último mes son: 42
# BricoDepot. Calle Juliano, 12
# Las ventas de los últimos meses han sido: 70
# La media de ventas por empleado es 11.666666666666666
# Las ventas de los últimos meses son: 105.0
# Las ventas del último mes son: 4032
# MediaMarkt. Av. Prim y Mas, 12
# Las ventas de los últimos meses han sido: 7400
# La media de ventas por empleado es 145.09803921568627
# Las ventas de los últimos meses son: 11100.0

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro:
    legs = 4
    ears = 2
    eyes = 2
    speed = 0

    def __init__(self, breed, color, owner):
        self.breed = "German Speech"
        self.color = "Marrón"
        self.owner = False
    
    def walk(self):
        
        aumento_vel = input("A que velocidad se mueve el perro?")
        self.speed = int(aumento_vel) + self.speed
        return "El perro esta moviendose a una velocidad de " + str(self.speed) + " m/h"
    
    def stop(self):
        self.speed = 0
        return "El perro se ha parado"
    
    def barking(self):
        bark_1 = input("Que quiere decir el perro?")
        bark = "WOF!" + "eso significa: " + bark_1
        return "El perro ha dicho, " + bark
    
perro1 = Perro("Pomeranian", "Oranje", True)


print(perro1.breed)
print(perro1.color)
print(perro1.barking())
print(perro1.speed)
print(perro1.walk())
print(perro1.stop())
print(perro1.owner)
# Out:
# German Speech
# Marrón
# El perro ha dicho, WOF!eso significa: HOla
# 0
# El perro esta moviendose a una velocidad de 23 m/h
# El perro se ha parado
# False
